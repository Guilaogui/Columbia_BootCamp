# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")
#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=coquimbo
# Processing Record 2 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=atuona
# Processing Record 3 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ushuaia
# Processing Record 4 | Tezpur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tezpur
# Processing Record 5 | Beitbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=beitbridge
# Processing Record 6 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=east london
# Processing Record 7 | Pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pisco
# Processing Record 8 | Corowa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=corowa
# Processing Record 9 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vaini
# Processing Record 10 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hobart
# Processing Record 11 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=longyearbyen
# Processing Record 12 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bredasdorp
# Processing Record 13 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=albany
# Processing Record 14 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=haines junction
# City not found. Skipping...
# Processing Record 15 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bethel
# Processing Record 16 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saldanha
# Processing Record 17 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mahebourg
# Processing Record 18 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cape town
# Processing Record 19 | Evensk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=evensk
# Processing Record 20 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pevek
# Processing Record 21 | Salaga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=salaga
# Processing Record 22 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=shingu
# City not found. Skipping...
# Processing Record 23 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rikitea
# Processing Record 24 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hualmay
# Processing Record 25 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=komsomolskiy
# Processing Record 26 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=punta arenas
# Processing Record 27 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san cristobal
# Processing Record 28 | Dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dunedin
# Processing Record 29 | Morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=morondava
# Processing Record 30 | Gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=gat
# Processing Record 31 | Glazunovka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=glazunovka
# Processing Record 32 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=castro
# Processing Record 33 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kapaa
# Processing Record 34 | Sharan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sharan
# Processing Record 35 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=severo-kurilsk
# Processing Record 36 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mataura
# Processing Record 37 | Seoul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=seoul
# City not found. Skipping...
# Processing Record 38 | Quatre Cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=quatre cocos
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 | Richards Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=richards bay
# Processing Record 40 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yar-sale
# Processing Record 41 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=carnarvon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=clyde river
# Processing Record 43 | West Wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=west wendover
# Processing Record 44 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mount gambier
# Processing Record 45 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=upernavik
# Processing Record 46 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tuktoyaktuk
# City not found. Skipping...
# Processing Record 47 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yellowknife
# Processing Record 48 | Srivardhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=srivardhan
# Processing Record 49 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hilo
# Processing Record 50 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=jamestown
# Processing Record 51 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sur
# Processing Record 52 | Tahe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tahe
# City not found. Skipping...
# Processing Record 53 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=naze
# Processing Record 54 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=namatanai
# Processing Record 55 | Ganta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ganta
# Processing Record 56 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=santa maria
# Processing Record 57 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chuy
# Processing Record 58 | Hagere Selam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hagere selam
# Processing Record 59 | Saquarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saquarema
# Processing Record 60 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lebu
# Processing Record 61 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bambous virieux
# Processing Record 62 | Sapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sapa
# Processing Record 63 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kruisfontein
# Processing Record 64 | Gwadar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=gwadar
# Processing Record 65 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=qaanaaq
# Processing Record 66 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=makakilo city
# Processing Record 67 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=portland
# Processing Record 68 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=arraial do cabo
# Processing Record 69 | Chontalpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chontalpa
# Processing Record 70 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=busselton
# Processing Record 71 | Avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=avera
# Processing Record 72 | Englewood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=englewood
# Processing Record 73 | Morro Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=morro bay
# Processing Record 74 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tilichiki
# Processing Record 75 | Newport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=newport
# Processing Record 76 | Zirandaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zirandaro
# Processing Record 77 | Severo-Yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=severo-yeniseyskiy
# Processing Record 78 | Fallon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fallon
# Processing Record 79 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=new norfolk
# Processing Record 80 | Adet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=adet
# Processing Record 81 | Burdur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=burdur
# Processing Record 82 | Mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mackay
# Processing Record 83 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=leningradskiy
# Processing Record 84 | Svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=svetlaya
# Processing Record 85 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=salalah
# Processing Record 86 | Pincher Creek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pincher creek
# Processing Record 87 | Manggar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=manggar
# Processing Record 88 | San Jose
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san jose
# Processing Record 89 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=provideniya
# Processing Record 90 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mehamn
# Processing Record 91 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=caravelas
# Processing Record 92 | Nong Phai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nong phai
# Processing Record 93 | Dawei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dawei
# Processing Record 94 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nikolskoye
# Processing Record 95 | Rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rocha
# Processing Record 96 | Praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=praia
# Processing Record 97 | Korem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=korem
# Processing Record 98 | Navalcarnero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=navalcarnero
# Processing Record 99 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kaitangata
# Processing Record 100 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bluff
# Processing Record 101 | Apac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=apac
# Processing Record 102 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=namibe
# Processing Record 103 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vardo
# Processing Record 104 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hasaki
# Processing Record 105 | Taseyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=taseyevo
# Processing Record 106 | Renqiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=renqiu
# Processing Record 107 | Kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kendari
# Processing Record 108 | Aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aquiraz
# Processing Record 109 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ribeira grande
# Processing Record 110 | Hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hami
# Processing Record 111 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hithadhoo
# Processing Record 112 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=katsuura
# Processing Record 113 | Half Moon Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=half moon bay
# Processing Record 114 | Douentza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=douentza
# Processing Record 115 | Isla Mujeres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=isla mujeres
# Processing Record 116 | Houston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=houston
# Processing Record 117 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto ayora
# Processing Record 118 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=poum
# City not found. Skipping...
# Processing Record 119 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lagoa
# Processing Record 120 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kahului
# Processing Record 121 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nome
# Processing Record 122 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rawson
# City not found. Skipping...
# Processing Record 123 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=buchanan
# Processing Record 124 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kodiak
# City not found. Skipping...
# Processing Record 125 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=itarema
# Processing Record 126 | Bani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bani
# Processing Record 127 | Bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bud
# Processing Record 128 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint george
# Processing Record 129 | Poya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=poya
# Processing Record 130 | Ucluelet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ucluelet
# City not found. Skipping...
# Processing Record 131 | Carthage
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=carthage
# Processing Record 132 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=touros
# Processing Record 133 | Brodnica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=brodnica
# Processing Record 134 | Benghazi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=benghazi
# Processing Record 135 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dikson
# Processing Record 136 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=avarua
# Processing Record 137 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=butaritari
# Processing Record 138 | Husavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=husavik
# Processing Record 139 | Bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bowen
# Processing Record 140 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=khatanga
# Processing Record 141 | Kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kutum
# Processing Record 142 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mayo
# City not found. Skipping...
# Processing Record 143 | Lagoa Vermelha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lagoa vermelha
# Processing Record 144 | Bekhtery
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bekhtery
# Processing Record 145 | Maseru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=maseru
# Processing Record 146 | Barkot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=barkot
# City not found. Skipping...
# Processing Record 147 | Matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=matay
# Processing Record 148 | Boda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=boda
# Processing Record 149 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bonavista
# Processing Record 150 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=constitucion
# City not found. Skipping...
# Processing Record 151 | Kuliyapitiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kuliyapitiya
# Processing Record 152 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hofn
# Processing Record 153 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zhigansk
# Processing Record 154 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=beyneu
# Processing Record 155 | Uvat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=uvat
# Processing Record 156 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=iqaluit
# Processing Record 157 | Ciudad Bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ciudad bolivar
# Processing Record 158 | Ust-Koksa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ust-koksa
# Processing Record 159 | Sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sibu
# Processing Record 160 | Vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vaitape
# Processing Record 161 | Nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nantucket
# Processing Record 162 | Tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tanout
# Processing Record 163 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=norman wells
# Processing Record 164 | Muyuka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=muyuka
# Processing Record 165 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=banda aceh
# City not found. Skipping...
# Processing Record 166 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=burnie
# Processing Record 167 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=isangel
# Processing Record 168 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san patricio
# Processing Record 169 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port elizabeth
# Processing Record 170 | Vanino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vanino
# Processing Record 171 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=roma
# City not found. Skipping...
# Processing Record 172 | Yangambi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yangambi
# Processing Record 173 | Mariinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mariinsk
# Processing Record 174 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chernyshevskiy
# Processing Record 175 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saskylakh
# Processing Record 176 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fortuna
# Processing Record 177 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-pierre
# Processing Record 178 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ponta delgada
# Processing Record 179 | Maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=maragogi
# Processing Record 180 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lasa
# Processing Record 181 | Kindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kindu
# City not found. Skipping...
# Processing Record 182 | Khilok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=khilok
# Processing Record 183 | Tommot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tommot
# Processing Record 184 | Mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mahibadhoo
# Processing Record 185 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=luderitz
# City not found. Skipping...
# Processing Record 186 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vao
# Processing Record 187 | Lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lompoc
# City not found. Skipping...
# Processing Record 188 | Manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=manokwari
# City not found. Skipping...
# Processing Record 189 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=guerrero negro
# City not found. Skipping...
# Processing Record 190 | Kisangani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kisangani
# Processing Record 191 | Ankang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ankang
# City not found. Skipping...
# Processing Record 192 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=noumea
# City not found. Skipping...
# Processing Record 193 | Shimoda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=shimoda
# Processing Record 194 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sisimiut
# Processing Record 195 | Vendome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vendome
# Processing Record 196 | Sicamous
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sicamous
# Processing Record 197 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cherskiy
# Processing Record 198 | Norilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=norilsk
# Processing Record 199 | Gerash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=gerash
# Processing Record 200 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port alfred
# Processing Record 201 | Camapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=camapua
# City not found. Skipping...
# Processing Record 202 | Nanchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nanchang
# Processing Record 203 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=taltal
# Processing Record 204 | Tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tabas
# Processing Record 205 | Iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=iracoubo
# Processing Record 206 | Palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=palmer
# City not found. Skipping...
# Processing Record 207 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dwarka
# Processing Record 208 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kavieng
# Processing Record 209 | Gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=gizo
# Processing Record 210 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bahia blanca
# City not found. Skipping...
# Processing Record 211 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=moron
# Processing Record 212 | Bayangol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bayangol
# Processing Record 213 | Along
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=along
# Processing Record 214 | Felanitx
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=felanitx
# Processing Record 215 | Peace River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=peace river
# Processing Record 216 | Matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=matagami
# Processing Record 217 | Baryatino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=baryatino
# Processing Record 218 | Marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=marzuq
# Processing Record 219 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hermanus
# Processing Record 220 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pacific grove
# Processing Record 221 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ahipara
# Processing Record 222 | Odienne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=odienne
# City not found. Skipping...
# Processing Record 223 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=faanui
# Processing Record 224 | Lodwar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lodwar
# Processing Record 225 | Menomonie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=menomonie
# Processing Record 226 | Yarkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yarkovo
# Processing Record 227 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=thompson
# Processing Record 228 | San Policarpo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san policarpo
# City not found. Skipping...
# Processing Record 229 | Loukhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=loukhi
# Processing Record 230 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mar del plata
# Processing Record 231 | Savannah Bight
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=savannah bight
# Processing Record 232 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fairbanks
# Processing Record 233 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=la ronge
# Processing Record 234 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tasiilaq
# Processing Record 235 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao filipe
# Processing Record 236 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=barrow
# Processing Record 237 | Outjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=outjo
# Processing Record 238 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=torbay
# Processing Record 239 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=georgetown
# Processing Record 240 | Rio Gallegos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rio gallegos
# Processing Record 241 | Changji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=changji
# Processing Record 242 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ilulissat
# Processing Record 243 | Kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kuytun
# Processing Record 244 | Villaviciosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=villaviciosa
# Processing Record 245 | Walvis Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=walvis bay
# Processing Record 246 | Puerto Padre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto padre
# Processing Record 247 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-philippe
# Processing Record 248 | San Vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san vicente
# Processing Record 249 | Moose Factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=moose factory
# Processing Record 250 | Tirano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tirano
# Processing Record 251 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tiksi
# Processing Record 252 | Quincy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=quincy
# Processing Record 253 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=laguna
# Processing Record 254 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aykhal
# Processing Record 255 | Vieste
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vieste
# Processing Record 256 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=esperance
# Processing Record 257 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ponta do sol
# Processing Record 258 | Chimore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chimore
# Processing Record 259 | Mehran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mehran
# Processing Record 260 | Homer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=homer
# Processing Record 261 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=olinda
# Processing Record 262 | Panguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=panguna
# Processing Record 263 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=viedma
# Processing Record 264 | Sawtell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sawtell
# Processing Record 265 | Mashhad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mashhad
# Processing Record 266 | Aranos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aranos
# Processing Record 267 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=belaya gora
# Processing Record 268 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=wanning
# Processing Record 269 | Ilhabela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ilhabela
# Processing Record 270 | Zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zhangjiakou
# Processing Record 271 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hambantota
# Processing Record 272 | Am Timan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=am timan
# Processing Record 273 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=alofi
# Processing Record 274 | Tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tiznit
# Processing Record 275 | Bafq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bafq
# City not found. Skipping...
# Processing Record 276 | Callaway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=callaway
# Processing Record 277 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=launceston
# Processing Record 278 | Cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cabra
# Processing Record 279 | Qiongshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=qiongshan
# Processing Record 280 | Agfalva
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=agfalva
# Processing Record 281 | Hopkinsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hopkinsville
# Processing Record 282 | Mungaoli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mungaoli
# Processing Record 283 | Guiratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=guiratinga
# Processing Record 284 | Keetmanshoop
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=keetmanshoop
# Processing Record 285 | Little Falls
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=little falls
# Processing Record 286 | Ornskoldsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ornskoldsvik
# Processing Record 287 | Necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=necochea
# Processing Record 288 | Somerset
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=somerset
# Processing Record 289 | Cockburn Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cockburn town
# Processing Record 290 | Saint-Augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-augustin
# Processing Record 291 | Tambilil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tambilil
# Processing Record 292 | Nuevo Progreso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nuevo progreso
# City not found. Skipping...
# Processing Record 293 | Boueni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=boueni
# Processing Record 294 | Mari-Turek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mari-turek
# City not found. Skipping...
# Processing Record 295 | Beeville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=beeville
# Processing Record 296 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=waingapu
# Processing Record 297 | Kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kikwit
# Processing Record 298 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=maniitsoq
# Processing Record 299 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sitka
# Processing Record 300 | Sao Sebastiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao sebastiao
# Processing Record 301 | Malartic
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=malartic
# Processing Record 302 | Santa Cruz del Norte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=santa cruz del norte
# Processing Record 303 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sioux lookout
# Processing Record 304 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=solnechnyy
# Processing Record 305 | Carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=carauari
# Processing Record 306 | Springfield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=springfield
# Processing Record 307 | Linqiong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=linqiong
# Processing Record 308 | Yeniseysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yeniseysk
# City not found. Skipping...
# Processing Record 309 | Amposta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=amposta
# Processing Record 310 | Comodoro Rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=comodoro rivadavia
# Processing Record 311 | Bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bosaso
# Processing Record 312 | Zhanakorgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zhanakorgan
# Processing Record 313 | Soubre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=soubre
# Processing Record 314 | Khotyn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=khotyn
# Processing Record 315 | Sao Joao dos Patos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao joao dos patos
# Processing Record 316 | Samarai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=samarai
# Processing Record 317 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=inhambane
# Processing Record 318 | Tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 319 | Warwick
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=warwick
# City not found. Skipping...
# Processing Record 320 | Rio Cuarto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rio cuarto
# Processing Record 321 | Oussouye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=oussouye
# Processing Record 322 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=eyl
# Processing Record 323 | Zambezi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zambezi
# Processing Record 324 | Victoria
# ...
# Processing Record 447 | La Roda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=la roda
# Processing Record 448 | Dolores
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dolores
# City not found. Skipping...
# Processing Record 449 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=boa vista
# Processing Record 450 | Cheremukhovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cheremukhovo
# Processing Record 451 | Majene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=majene
# City not found. Skipping...
# Processing Record 452 | Jalpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=jalpa
# Processing Record 453 | Ezhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ezhou
# City not found. Skipping...
# Processing Record 454 | Abu Kamal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=abu kamal
# City not found. Skipping...
# Processing Record 455 | Kamnik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kamnik
# Processing Record 456 | Hastinapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hastinapur
# Processing Record 457 | Agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=agadez
# Processing Record 458 | Sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sumbe
# Processing Record 459 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=baykit
# Processing Record 460 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yumen
# Processing Record 461 | Phan Thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=phan thiet
# Processing Record 462 | Mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mandalgovi
# Processing Record 463 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao joao da barra
# Processing Record 464 | Xuddur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=xuddur
# Processing Record 465 | Kungalv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kungalv
# Processing Record 466 | Yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yatou
# Processing Record 467 | Dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dukat
# Processing Record 468 | Kapuskasing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kapuskasing
# Processing Record 469 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=college
# Processing Record 470 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aksarka
# Processing Record 471 | Katete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=katete
# Processing Record 472 | Yuanping
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yuanping
# Processing Record 473 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vestmannaeyjar
# Processing Record 474 | Smithers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=smithers
# Processing Record 475 | Palora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=palora
# Processing Record 476 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=arlit
# Processing Record 477 | Sosnovo-Ozerskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sosnovo-ozerskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 478 | Sarahan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sarahan
# Processing Record 479 | Manzanillo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=manzanillo
# Processing Record 480 | Ivankiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ivankiv
# Processing Record 481 | Pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pedernales
# Processing Record 482 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=klaksvik
# Processing Record 483 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lethem
# Processing Record 484 | Naruto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=naruto
# Processing Record 485 | Jieshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=jieshi
# City not found. Skipping...
# Processing Record 486 | Shwebo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=shwebo
# Processing Record 487 | Baglung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=baglung
# Processing Record 488 | Bonnyville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bonnyville
# Processing Record 489 | Manvi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=manvi
# Processing Record 490 | Chirongui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chirongui
# Processing Record 491 | Basmat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=basmat
# City not found. Skipping...
# Processing Record 492 | Port Hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port hedland
# Processing Record 493 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=luganville
# Processing Record 494 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ayan
# Processing Record 495 | Bilibino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bilibino
# Processing Record 496 | Udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=udachnyy
# Processing Record 497 | Agadir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=agadir
# Processing Record 498 | Hanyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hanyang
# Processing Record 499 | Yabelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yabelo
# Processing Record 500 | Discovery Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=discovery bay
# Processing Record 501 | Chateauroux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chateauroux
# Processing Record 502 | Gonbad-e Qabus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=gonbad-e qabus
# Processing Record 503 | Mackenzie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mackenzie
# Processing Record 504 | Raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=raudeberg
# Processing Record 505 | Bar Harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bar harbor
# Processing Record 506 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=opuwo
# Processing Record 507 | Sungairaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sungairaya
# Processing Record 508 | Mongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mongo
# Processing Record 509 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=riyadh
# Processing Record 510 | General Bravo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=general bravo
# Processing Record 511 | Mglin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mglin
# Processing Record 512 | Badarwas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=badarwas
# Processing Record 513 | Bogande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bogande
# City not found. Skipping...
# Processing Record 514 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nemuro
# Processing Record 515 | Changchun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=changchun
# Processing Record 516 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lavrentiya
# Processing Record 517 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=auki
# Processing Record 518 | Puro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puro
# Processing Record 519 | Rock Sound
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rock sound
# Processing Record 520 | Ereymentau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ereymentau
# Processing Record 521 | Campobasso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=campobasso
# Processing Record 522 | Pamplonita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pamplonita
# Processing Record 523 | Antigonish
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=antigonish
# Processing Record 524 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kiama
# Processing Record 525 | Banjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=banjar
# Processing Record 526 | Wahiawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=wahiawa
# Processing Record 527 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=leh
# City not found. Skipping...
# Processing Record 528 | Ozinki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ozinki
# Processing Record 529 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aksu
# Processing Record 530 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=salinopolis
# Processing Record 531 | Zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zyryanka
# Processing Record 532 | Barmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=barmer
# Processing Record 533 | Ingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ingham
# Processing Record 534 | Pozo Colorado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pozo colorado
# Processing Record 535 | Channahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=channahon
# Processing Record 536 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=deputatskiy
# Processing Record 537 | Antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=antofagasta
# Processing Record 538 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pitimbu
# Processing Record 539 | Grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=grindavik
# City not found. Skipping...
# Processing Record 540 | Roald
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=roald
# Processing Record 541 | Calbiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=calbiga
# Processing Record 542 | Itoman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=itoman
# City not found. Skipping...
# Processing Record 543 | Sanquelim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sanquelim
# Processing Record 544 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cabo san lucas
# Processing Record 545 | Torbat-e Jam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=torbat-e jam
# Processing Record 546 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ancud
# Processing Record 547 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mitsamiouli
# Processing Record 548 | Bozova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bozova
# Processing Record 549 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aklavik
# Processing Record 550 | Atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=atasu
# Processing Record 551 | Quepos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=quepos
# Processing Record 552 | Oyem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=oyem
# Processing Record 553 | Damavand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=damavand
# Processing Record 554 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vila franca do campo

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | bisignano
# Processing Record 4 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | ashland
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | port macquarie
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | srednekolymsk
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | ivaipora
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | ambilobe
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | namatanai
# Processing Record 31 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | muros
# Processing Record 36 of Set 1 | tamandare
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | lumut
# Processing Record 40 of Set 1 | sukumo
# Processing Record 41 of Set 1 | chapais
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | ordzhonikidze
# Processing Record 44 of Set 1 | jiangyou
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | vila franca do campo
# Processing Record 47 of Set 1 | shchelkun
# Processing Record 48 of Set 1 | vanimo
# Processing Record 49 of Set 1 | kalmanhaza
# Processing Record 50 of Set 1 | butaritari
# Processing Record 0 of Set 2 | codrington
# Processing Record 1 of Set 2 | ayolas
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | tessalit
# Processing Record 6 of Set 2 | panguna
# Processing Record 7 of Set 2 | cockburn town
# Processing Record 8 of Set 2 | valerianovsk
# Processing Record 9 of Set 2 | tingrela
# City not found. Skipping...
# Processing Record 10 of Set 2 | novobirilyussy
# Processing Record 11 of Set 2 | krasnoborsk
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 2 | vila do maio
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 2 | livani
# Processing Record 21 of Set 2 | urucui
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | bocaiuva
# Processing Record 27 of Set 2 | jiexiu
# Processing Record 28 of Set 2 | quelimane
# Processing Record 29 of Set 2 | rujewa
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | belyy yar
# Processing Record 35 of Set 2 | venezuela
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | mitsamiouli
# Processing Record 40 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 2 | bunia
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | kudahuvadhoo
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | okhotsk
# Processing Record 47 of Set 2 | muzaffarabad
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | esperance
# Processing Record 0 of Set 3 | arenapolis
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | nemuro
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | rio gallegos
# Processing Record 5 of Set 3 | svetlaya
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 3 | mandalgovi
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | pemangkat
# City not found. Skipping...
# Processing Record 13 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 3 | qiqihar
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | amnat charoen
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | luang prabang
# Processing Record 23 of Set 3 | hami
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | kyren
# Processing Record 26 of Set 3 | yuanping
# Processing Record 27 of Set 3 | dukat
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | dorfen
# Processing Record 31 of Set 3 | ayan
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | vertientes
# Processing Record 36 of Set 3 | charters towers
# Processing Record 37 of Set 3 | nenjiang
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | puerto del rosario
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | maldonado
# Processing Record 43 of Set 3 | bintulu
# Processing Record 44 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | vardo
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | muzhi
# Processing Record 49 of Set 3 | zhangye
# Processing Record 0 of Set 4 | nouadhibou
# Processing Record 1 of Set 4 | oussouye
# Processing Record 2 of Set 4 | agaro
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | pacific grove
# Processing Record 8 of Set 4 | half moon bay
# Processing Record 9 of Set 4 | goderich
# Processing Record 10 of Set 4 | severnyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | erenhot
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | agadez
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | drummondville
# Processing Record 16 of Set 4 | selfoss
# Processing Record 17 of Set 4 | carman
# Processing Record 18 of Set 4 | kurumkan
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | osakarovka
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | pec
# Processing Record 23 of Set 4 | nacala
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | ewo
# Processing Record 26 of Set 4 | alihe
# Processing Record 27 of Set 4 | felipe carrillo puerto
# Processing Record 28 of Set 4 | sept-iles
# Processing Record 29 of Set 4 | anzio
# Processing Record 30 of Set 4 | abeche
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | yatou
# Processing Record 34 of Set 4 | pangkalanbuun
# Processing Record 35 of Set 4 | namibe
# Processing Record 36 of Set 4 | caltagirone
# Processing Record 37 of Set 4 | araguacu
# City not found. Skipping...
# Processing Record 38 of Set 4 | atuntaqui
# Processing Record 39 of Set 4 | marshfield
# Processing Record 40 of Set 4 | saint-joseph
# Processing Record 41 of Set 4 | chambas
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | abadan
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | axim
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | voh
# Processing Record 48 of Set 4 | puerto ayora
# Processing Record 49 of Set 4 | sinnamary
# Processing Record 0 of Set 5 | duz
# City not found. Skipping...
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | port hardy
# Processing Record 3 of Set 5 | vieste
# Processing Record 4 of Set 5 | dalvik
# Processing Record 5 of Set 5 | tual
# Processing Record 6 of Set 5 | novopokrovka
# Processing Record 7 of Set 5 | soyo
# Processing Record 8 of Set 5 | broken hill
# Processing Record 9 of Set 5 | columbia
# Processing Record 10 of Set 5 | sao joao da barra
# Processing Record 11 of Set 5 | lumphat
# Processing Record 12 of Set 5 | ciudad bolivar
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | bredasdorp
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | samaniego
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | sarangani
# Processing Record 26 of Set 5 | bontang
# Processing Record 27 of Set 5 | jacareacanga
# Processing Record 28 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 5 | raudeberg
# Processing Record 30 of Set 5 | terrenate
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | asau
# City not found. Skipping...
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | bure
# Processing Record 35 of Set 5 | ranot
# Processing Record 36 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 5 | merauke
# Processing Record 38 of Set 5 | prichard
# Processing Record 39 of Set 5 | gravelbourg
# Processing Record 40 of Set 5 | searcy
# Processing Record 41 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | sisimiut
# Processing Record 44 of Set 5 | trelew
# Processing Record 45 of Set 5 | aban
# City not found. Skipping...
# Processing Record 46 of Set 5 | vakhrushev
# Processing Record 47 of Set 5 | pierre
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | lorengau
# Processing Record 0 of Set 6 | mokrousovo
# Processing Record 1 of Set 6 | baltay
# Processing Record 2 of Set 6 | kainantu
# Processing Record 3 of Set 6 | goulburn
# Processing Record 4 of Set 6 | lincoln
# Processing Record 5 of Set 6 | harnosand
# Processing Record 6 of Set 6 | camana
# City not found. Skipping...
# Processing Record 7 of Set 6 | pleshanovo
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | porto novo
# Processing Record 10 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 11 of Set 6 | quatre cocos
# Processing Record 12 of Set 6 | marzuq
# Processing Record 13 of Set 6 | prince george
# Processing Record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 6 | sorsk
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | shihezi
# Processing Record 18 of Set 6 | coffs harbour
# Processing Record 19 of Set 6 | rasova
# Processing Record 20 of Set 6 | dingle
# Processing Record 21 of Set 6 | la primavera
# Processing Record 22 of Set 6 | tezu
# Processing Record 23 of Set 6 | qasigiannguit
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | peleduy
# Processing Record 26 of Set 6 | yei
# City not found. Skipping...
# Processing Record 27 of Set 6 | dakar
# Processing Record 28 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | buzuluk
# Processing Record 31 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 6 | ponferrada
# Processing Record 33 of Set 6 | kaeo
# Processing Record 34 of Set 6 | chimbote
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | kurkino
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | puri
# Processing Record 39 of Set 6 | maues
# Processing Record 40 of Set 6 | kapit
# Processing Record 41 of Set 6 | sinegorye
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 6 | itaueira
# Processing Record 45 of Set 6 | georgetown
# Processing Record 46 of Set 6 | parana
# Processing Record 47 of Set 6 | govindgarh
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | tura
# Processing Record 0 of Set 7 | nhulunbuy
# Processing Record 1 of Set 7 | buala
# Processing Record 2 of Set 7 | ngunguru
# Processing Record 3 of Set 7 | abu zabad
# Processing Record 4 of Set 7 | katete
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | fayaoue
# Processing Record 7 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | omsukchan
# Processing Record 10 of Set 7 | la asuncion
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | matagami
# Processing Record 13 of Set 7 | palmer
# Processing Record 14 of Set 7 | dzhebariki-khaya
# Processing Record 15 of Set 7 | shitanjing
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | bethel
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | isiolo
# Processing Record 22 of Set 7 | sao paulo de olivenca
# Processing Record 23 of Set 7 | buckeye
# Processing Record 24 of Set 7 | wewak
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 7 | la libertad
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | dicabisagan
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | wladyslawowo
# Processing Record 32 of Set 7 | kemin
# Processing Record 33 of Set 7 | coolum beach
# Processing Record 34 of Set 7 | rosetta
# Processing Record 35 of Set 7 | bermeo
# Processing Record 36 of Set 7 | turtas
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | key west
# Processing Record 39 of Set 7 | aklavik
# Processing Record 40 of Set 7 | tikapur
# Processing Record 41 of Set 7 | oranjestad
# Processing Record 42 of Set 7 | calvinia
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | gaziantep
# Processing Record 45 of Set 7 | port augusta
# Processing Record 46 of Set 7 | turukhansk
# Processing Record 47 of Set 7 | roma
# Processing Record 48 of Set 7 | buraydah
# Processing Record 49 of Set 7 | andenes
# City not found. Skipping...
# Processing Record 0 of Set 8 | coihaique
# Processing Record 1 of Set 8 | surt
# Processing Record 2 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 8 | nanjangud
# Processing Record 4 of Set 8 | saravan
# Processing Record 5 of Set 8 | penzance
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | baherden
# Processing Record 8 of Set 8 | minbu
# Processing Record 9 of Set 8 | hamina
# Processing Record 10 of Set 8 | mackay
# Processing Record 11 of Set 8 | omaruru
# Processing Record 12 of Set 8 | roald
# Processing Record 13 of Set 8 | tashtyp
# Processing Record 14 of Set 8 | kyra
# City not found. Skipping...
# Processing Record 15 of Set 8 | walvis bay
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | le port
# Processing Record 18 of Set 8 | hokitika
# Processing Record 19 of Set 8 | guapi
# Processing Record 20 of Set 8 | manyana
# Processing Record 21 of Set 8 | airai
# Processing Record 22 of Set 8 | wajid
# Processing Record 23 of Set 8 | mumford
# Processing Record 24 of Set 8 | labuhan
# Processing Record 25 of Set 8 | sabang
# Processing Record 26 of Set 8 | batagay-alyta
# Processing Record 27 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 8 | gouyave
# Processing Record 29 of Set 8 | avera
# Processing Record 30 of Set 8 | zonguldak
# Processing Record 31 of Set 8 | tokur
# Processing Record 32 of Set 8 | pyay
# Processing Record 33 of Set 8 | ulladulla
# Processing Record 34 of Set 8 | grand-santi
# Processing Record 35 of Set 8 | urusha
# Processing Record 36 of Set 8 | lata
# Processing Record 37 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 38 of Set 8 | tazovskiy
# Processing Record 39 of Set 8 | kefamenanu
# Processing Record 40 of Set 8 | agva
# City not found. Skipping...
# Processing Record 41 of Set 8 | kysyl-syr
# Processing Record 42 of Set 8 | wajima
# Processing Record 43 of Set 8 | kargopol
# Processing Record 44 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 8 | ovalle
# Processing Record 46 of Set 8 | wadi musa
# Processing Record 47 of Set 8 | iguape
# Processing Record 48 of Set 8 | san juan
# Processing Record 49 of Set 8 | vinh
# Processing Record 0 of Set 9 | kuminskiy
# Processing Record 1 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 9 | honningsvag
# Processing Record 3 of Set 9 | harper
# Processing Record 4 of Set 9 | batasan
# Processing Record 5 of Set 9 | yumen
# Processing Record 6 of Set 9 | tutoia
# Processing Record 7 of Set 9 | tazmalt
# Processing Record 8 of Set 9 | lavrentiya
# Processing Record 9 of Set 9 | sarmanovo
# Processing Record 10 of Set 9 | edgewater
# Processing Record 11 of Set 9 | gushikawa
# Processing Record 12 of Set 9 | kalmunai
# Processing Record 13 of Set 9 | houma
# Processing Record 14 of Set 9 | vila
# Processing Record 15 of Set 9 | umba
# Processing Record 16 of Set 9 | pevek
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | termiz
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | maniitsoq
# Processing Record 21 of Set 9 | yuncheng
# Processing Record 22 of Set 9 | port shepstone
# Processing Record 23 of Set 9 | truth or consequences
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | necochea
# Processing Record 26 of Set 9 | broome
# Processing Record 27 of Set 9 | laredo
# Processing Record 28 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 9 | fort smith
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | ferme-neuve
# Processing Record 32 of Set 9 | dengzhou
# Processing Record 33 of Set 9 | kamennogorsk
# Processing Record 34 of Set 9 | padang
# Processing Record 35 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | huangchuan
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | tocopilla
# Processing Record 41 of Set 9 | rudbar
# City not found. Skipping...
# Processing Record 42 of Set 9 | galesong
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | narsaq
# Processing Record 45 of Set 9 | sungaipenuh
# Processing Record 46 of Set 9 | papara
# Processing Record 47 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 9 | isangel
# Processing Record 49 of Set 9 | kamyshlov
# Processing Record 0 of Set 10 | ponta do sol
# Processing Record 1 of Set 10 | lengshuitan
# Processing Record 2 of Set 10 | thinadhoo
# Processing Record 3 of Set 10 | saint anthony
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | kokopo
# Processing Record 6 of Set 10 | iqaluit
# Processing Record 7 of Set 10 | longyearbyen
# Processing Record 8 of Set 10 | los llanos de aridane
# Processing Record 9 of Set 10 | hayden
# Processing Record 10 of Set 10 | erzurum
# Processing Record 11 of Set 10 | bonthe
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | barkhan
# Processing Record 14 of Set 10 | euclides da cunha
# Processing Record 15 of Set 10 | sanghar
# Processing Record 16 of Set 10 | te anau
# Processing Record 17 of Set 10 | valleyview
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | banda aceh
# Processing Record 20 of Set 10 | tagusao
# Processing Record 21 of Set 10 | terrace
# Processing Record 22 of Set 10 | el chichicaste
# Processing Record 23 of Set 10 | gberia fotombu
# Processing Record 24 of Set 10 | ranir bazar
# Processing Record 25 of Set 10 | grindsted
# Processing Record 26 of Set 10 | katsuura
# Processing Record 27 of Set 10 | qaqortoq
# Processing Record 28 of Set 10 | pontes e lacerda
# Processing Record 29 of Set 10 | bata
# Processing Record 30 of Set 10 | kingston
# Processing Record 31 of Set 10 | aleksandrovka
# Processing Record 32 of Set 10 | vostok
# Processing Record 33 of Set 10 | puerto madryn
# Processing Record 34 of Set 10 | yuzhnyy
# Processing Record 35 of Set 10 | bulungu
# Processing Record 36 of Set 10 | kollam
# Processing Record 37 of Set 10 | progreso
# Processing Record 38 of Set 10 | visby
# Processing Record 39 of Set 10 | ilebo
# Processing Record 40 of Set 10 | ajdabiya
# Processing Record 41 of Set 10 | maine-soroa
# Processing Record 42 of Set 10 | sayreville
# Processing Record 43 of Set 10 | palana
# Processing Record 44 of Set 10 | acajutiba
# Processing Record 45 of Set 10 | lakatoro
# Processing Record 46 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 47 of Set 10 | lakes entrance
# Processing Record 48 of Set 10 | ludza
# Processing Record 49 of Set 10 | zvishavane
# Processing Record 0 of Set 11 | mao
# Processing Record 1 of Set 11 | seaham
# Processing Record 2 of Set 11 | kaa-khem
# Processing Record 3 of Set 11 | grindavik
# Processing Record 4 of Set 11 | pangody
# Processing Record 5 of Set 11 | zhuzhou
# Processing Record 6 of Set 11 | clyde river
# Processing Record 7 of Set 11 | estelle
# Processing Record 8 of Set 11 | ulaanbaatar
# Processing Record 9 of Set 11 | victoria point
# Processing Record 10 of Set 11 | flores
# Processing Record 11 of Set 11 | cairns
# Processing Record 12 of Set 11 | beyneu
# Processing Record 13 of Set 11 | hoquiam
# Processing Record 14 of Set 11 | kurilsk
# Processing Record 15 of Set 11 | albuquerque
# Processing Record 16 of Set 11 | tomatlan
# Processing Record 17 of Set 11 | blackfoot
# Processing Record 18 of Set 11 | anito
# Processing Record 19 of Set 11 | meybod
# Processing Record 20 of Set 11 | muscat
# Processing Record 21 of Set 11 | san patricio
# Processing Record 22 of Set 11 | pali
# Processing Record 23 of Set 11 | atambua
# Processing Record 24 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 11 | kuytun
# Processing Record 26 of Set 11 | lamu
# Processing Record 27 of Set 11 | bandarbeyla
# Processing Record 28 of Set 11 | eenhana
# Processing Record 29 of Set 11 | newburn
# Processing Record 30 of Set 11 | changli
# Processing Record 31 of Set 11 | toowoomba
# Processing Record 32 of Set 11 | banjar
# Processing Record 33 of Set 11 | hohhot
# Processing Record 34 of Set 11 | debre birhan
# Processing Record 35 of Set 11 | nelson bay
# Processing Record 36 of Set 11 | sibu
# Processing Record 37 of Set 11 | black river
# City not found. Skipping...
# Processing Record 38 of Set 11 | thaba-tseka
# Processing Record 39 of Set 11 | hobyo
# Processing Record 40 of Set 11 | bela vista de goias
# Processing Record 41 of Set 11 | ugoofaaru
# Processing Record 42 of Set 11 | dali
# Processing Record 43 of Set 11 | kadaya
# Processing Record 44 of Set 11 | kensington
# Processing Record 45 of Set 11 | zhigansk
# Processing Record 46 of Set 11 | merritt island
# Processing Record 47 of Set 11 | yamada
# Processing Record 48 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 11 | baghdad
# Processing Record 0 of Set 12 | havre-saint-pierre
# Processing Record 1 of Set 12 | alta floresta
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | wuwei
# Processing Record 4 of Set 12 | arman
# Processing Record 5 of Set 12 | salamiyah
# Processing Record 6 of Set 12 | vestmannaeyjar
# Processing Record 7 of Set 12 | dondo
# Processing Record 8 of Set 12 | gallup
# Processing Record 9 of Set 12 | micheweni
# Processing Record 10 of Set 12 | yanam
# Processing Record 11 of Set 12 | nipawin
# Processing Record 12 of Set 12 | jalu
# Processing Record 13 of Set 12 | brae
# Processing Record 14 of Set 12 | alappuzha
# City not found. Skipping...
# Processing Record 15 of Set 12 | leonidovo
# Processing Record 16 of Set 12 | krasnyy yar
# Processing Record 17 of Set 12 | nyimba
# Processing Record 18 of Set 12 | simao
# Processing Record 19 of Set 12 | kharsia
# Processing Record 20 of Set 12 | asekeyevo
# Processing Record 21 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 12 | les herbiers
# Processing Record 23 of Set 12 | bonavista
# Processing Record 24 of Set 12 | belaya gora
# Processing Record 25 of Set 12 | gao
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | porechye-rybnoye
# Processing Record 28 of Set 12 | san andres
# Processing Record 29 of Set 12 | fairbanks
# Processing Record 30 of Set 12 | george
# Processing Record 31 of Set 12 | bradford
# Processing Record 32 of Set 12 | lago da pedra
# City not found. Skipping...
# Processing Record 33 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 34 of Set 12 | port lincoln
# Processing Record 35 of Set 12 | carutapera
# Processing Record 36 of Set 12 | awjilah
# Processing Record 37 of Set 12 | naryan-mar
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | natal
# Processing Record 40 of Set 12 | nevsehir
# Processing Record 41 of Set 12 | turayf
# Processing Record 42 of Set 12 | temiscaming
# Processing Record 43 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 44 of Set 12 | kupang
# Processing Record 45 of Set 12 | port-cartier
# Processing Record 46 of Set 12 | storm lake
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | julich
# Processing Record 49 of Set 12 | makung
# City not found. Skipping...
# Processing Record 0 of Set 13 | viedma
# Processing Record 1 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 13 | sarkand
# Processing Record 3 of Set 13 | jhang
# Processing Record 4 of Set 13 | naze
# Processing Record 5 of Set 13 | zory
# Processing Record 6 of Set 13 | labuan
# Processing Record 7 of Set 13 | luwuk
# Processing Record 8 of Set 13 | sao felix do xingu
# Processing Record 9 of Set 13 | fonte boa
# Processing Record 10 of Set 13 | mahibadhoo
# Processing Record 11 of Set 13 | loukhi
# Processing Record 12 of Set 13 | mount isa
# Processing Record 13 of Set 13 | kargasok
# Processing Record 14 of Set 13 | mandera
# Processing Record 15 of Set 13 | praya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Save data frame to CSV
weather_data.to_csv('Output_CSV/weather_data.csv')

# Display count of weather data values 
weather_data.count()
# Out:
# City          554
# Cloudiness    554
# Country       554
# Date          554
# Humidity      554
# Lat           554
# Lng           554
# Max Temp      554
# Wind Speed    554
# dtype: int64

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Display data frame head 
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Coquimbo          40      CL  1559779651        93 -29.95  -71.34
# 1      Atuona          26      PF  1559779653        76  -9.80 -139.03
# 2     Ushuaia           0      AR  1559779654        75 -54.81  -68.31
# 3      Tezpur         100      IN  1559779655        82  26.62   92.79
# 4  Beitbridge           0      ZA  1559779656        35 -22.21   29.99
#
#    Max Temp  Wind Speed
# 0     62.01        2.24
# 1     82.49       18.68
# 2     41.00        8.39
# 3     79.07        3.67
# 4     62.33        5.19

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Output_Plots/Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
