# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")
#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lorengau
# Processing Record 2 | Fairview
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fairview
# Processing Record 3 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=alice springs
# Processing Record 4 | Arica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=arica
# Processing Record 5 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=carnarvon
# Processing Record 6 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cidreira
# Processing Record 7 | Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pierre
# Processing Record 8 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=faya
# Processing Record 9 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mataura
# Processing Record 10 | Lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lavrentiya
# Processing Record 11 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=butaritari
# Processing Record 12 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rikitea
# Processing Record 13 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=iqaluit
# City not found. Skipping...
# Processing Record 14 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=naze
# Processing Record 15 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=avarua
# City not found. Skipping...
# Processing Record 16 | Broken Hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=broken hill
# Processing Record 17 | Myitkyina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=myitkyina
# City not found. Skipping...
# Processing Record 18 | Areia Branca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=areia branca
# City not found. Skipping...
# Processing Record 19 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sisimiut
# Processing Record 20 | Pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pangai
# Processing Record 21 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto ayora
# Processing Record 22 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ushuaia
# Processing Record 23 | Berdigestyakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=berdigestyakh
# Processing Record 24 | Muroto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=muroto
# Processing Record 25 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=new norfolk
# Processing Record 26 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=namatanai
# Processing Record 27 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ribeira grande
# Processing Record 28 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tuktoyaktuk
# Processing Record 29 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cape town
# Processing Record 30 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pevek
# Processing Record 31 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=khatanga
# Processing Record 32 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=srednekolymsk
# Processing Record 33 | Akhaldaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=akhaldaba
# Processing Record 34 | Kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kavieng
# Processing Record 35 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cabo san lucas
# Processing Record 36 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=leningradskiy
# Processing Record 37 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port lincoln
# Processing Record 38 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=albany
# Processing Record 39 | Kinsale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kinsale
# Processing Record 40 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hobart
# Processing Record 41 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ballina
# Processing Record 42 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=severo-kurilsk
# City not found. Skipping...
# Processing Record 43 | Batticaloa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=batticaloa
# City not found. Skipping...
# Processing Record 44 | Luwuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=luwuk
# Processing Record 45 | Panaba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=panaba
# City not found. Skipping...
# Processing Record 46 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dikson
# City not found. Skipping...
# Processing Record 47 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hilo
# Processing Record 48 | Beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=beringovskiy
# Processing Record 49 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vaini
# Processing Record 50 | Milkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=milkovo
# Processing Record 51 | Makokou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=makokou
# Processing Record 52 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=punta arenas
# Processing Record 53 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=klaksvik
# Processing Record 54 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port elizabeth
# Processing Record 55 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nuuk
# Processing Record 56 | Flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=flinders
# Processing Record 57 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mar del plata
# Processing Record 58 | Acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=acapulco
# Processing Record 59 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=komsomolskiy
# Processing Record 60 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bluff
# Processing Record 61 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kapaa
# Processing Record 62 | Rudsar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rudsar
# City not found. Skipping...
# Processing Record 63 | Ozu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ozu
# Processing Record 64 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=birao
# Processing Record 65 | San Carlos de Bariloche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san carlos de bariloche
# Processing Record 66 | Nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nishihara
# Processing Record 67 | Sorland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sorland
# Processing Record 68 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=jamestown
# Processing Record 69 | Shilka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=shilka
# Processing Record 70 | Mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mareeba
# Processing Record 71 | Menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=menongue
# Processing Record 72 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=leshukonskoye
# City not found. Skipping...
# Processing Record 73 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=busselton
# Processing Record 74 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hithadhoo
# Processing Record 75 | Naberera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=naberera
# Processing Record 76 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tuatapere
# City not found. Skipping...
# Processing Record 77 | Oistins
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=oistins
# Processing Record 78 | San Ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san ramon
# Processing Record 79 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cherskiy
# Processing Record 80 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sitka
# Processing Record 81 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto escondido
# Processing Record 82 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=arraial do cabo
# Processing Record 83 | Hrodna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hrodna
# Processing Record 84 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=airai
# Processing Record 85 | Vuktyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vuktyl
# Processing Record 86 | Warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=warrnambool
# Processing Record 87 | Podporozhye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=podporozhye
# Processing Record 88 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hamilton
# Processing Record 89 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kodiak
# Processing Record 90 | Vanino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vanino
# Processing Record 91 | Halifax
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=halifax
# Processing Record 92 | Berberati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=berberati
# Processing Record 93 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=georgetown
# City not found. Skipping...
# Processing Record 94 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vila franca do campo
# Processing Record 95 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mount gambier
# Processing Record 96 | Seydi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=seydi
# Processing Record 97 | Outjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=outjo
# Processing Record 98 | Puerto Rico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto rico
# Processing Record 99 | Constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=constantine
# Processing Record 100 | Holme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=holme
# Processing Record 101 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mahebourg
# Processing Record 102 | Salinas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=salinas
# Processing Record 103 | Chornobay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chornobay
# City not found. Skipping...
# Processing Record 104 | Taseyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=taseyevo
# Processing Record 105 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=provideniya
# Processing Record 106 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=geraldton
# Processing Record 107 | Qasigiannguit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=qasigiannguit
# Processing Record 108 | Awjilah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=awjilah
# Processing Record 109 | Sao Jose da Tapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao jose da tapera
# Processing Record 110 | Fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fairbanks
# City not found. Skipping...
# Processing Record 111 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nanortalik
# Processing Record 112 | Skjervoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=skjervoy
# Processing Record 113 | Dabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dabat
# Processing Record 114 | Buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=buchanan
# Processing Record 115 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nikolskoye
# Processing Record 116 | San Ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san ignacio
# Processing Record 117 | Pestovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pestovo
# Processing Record 118 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=touros
# Processing Record 119 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tessalit
# Processing Record 120 | Riverton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=riverton
# Processing Record 121 | Bay Roberts
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bay roberts
# Processing Record 122 | Kiunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kiunga
# Processing Record 123 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bredasdorp
# Processing Record 124 | Lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lata
# Processing Record 125 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-philippe
# Processing Record 126 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kruisfontein
# Processing Record 127 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=atuona
# Processing Record 128 | Uruzgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=uruzgan
# Processing Record 129 | Vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vestmanna
# Processing Record 130 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lebu
# Processing Record 131 | Grand Forks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=grand forks
# Processing Record 132 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san cristobal
# Processing Record 133 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bonavista
# Processing Record 134 | Rome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=roma
# Processing Record 135 | Port Blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port blair
# Processing Record 136 | Le Havre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=le havre
# Processing Record 137 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yellowknife
# Processing Record 138 | Port-Gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port-gentil
# Processing Record 139 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=riyadh
# Processing Record 140 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ponta do sol
# Processing Record 141 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=east london
# Processing Record 142 | Xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=xining
# Processing Record 143 | Piracuruca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=piracuruca
# Processing Record 144 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=thompson
# Processing Record 145 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=makakilo city
# Processing Record 146 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=havre-saint-pierre
# Processing Record 147 | Fraga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fraga
# Processing Record 148 | Benjamin Aceval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=benjamin aceval
# Processing Record 149 | Gamboma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=gamboma
# Processing Record 150 | Moskovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=moskovskiy
# Processing Record 151 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vao
# Processing Record 152 | Charters Towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=charters towers
# Processing Record 153 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bambous virieux
# Processing Record 154 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=barrow
# Processing Record 155 | Pucallpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pucallpa
# Processing Record 156 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port alfred
# Processing Record 157 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kaitangata
# Processing Record 158 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fortuna
# Processing Record 159 | Shashi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=shashi
# Processing Record 160 | Beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=beyneu
# Processing Record 161 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hermanus
# Processing Record 162 | Terrace Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=terrace bay
# Processing Record 163 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kaeo
# Processing Record 164 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=coihaique
# Processing Record 165 | Bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bosaso
# Processing Record 166 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vardo
# Processing Record 167 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bethel
# City not found. Skipping...
# Processing Record 168 | Besuki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=besuki
# Processing Record 169 | Khandyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=khandyga
# City not found. Skipping...
# Processing Record 170 | Bahia Blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bahia blanca
# Processing Record 171 | Buenaventura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=buenaventura
# Processing Record 172 | Riachao das Neves
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=riachao das neves
# Processing Record 173 | Matara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=matara
# City not found. Skipping...
# Processing Record 174 | Troitsko-Pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=troitsko-pechorsk
# City not found. Skipping...
# Processing Record 175 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=victoria
# Processing Record 176 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nome
# Processing Record 177 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=torbay
# Processing Record 178 | Awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=awbari
# Processing Record 179 | San Jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san jeronimo
# Processing Record 180 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=castro
# Processing Record 181 | Salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=salinopolis
# Processing Record 182 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=norman wells
# Processing Record 183 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=upernavik
# Processing Record 184 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ancud
# Processing Record 185 | Brae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=brae
# Processing Record 186 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san patricio
# Processing Record 187 | Sioux Lookout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sioux lookout
# Processing Record 188 | Moletai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=moletai
# Processing Record 189 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pangnirtung
# Processing Record 190 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kieta
# Processing Record 191 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=guerrero negro
# Processing Record 192 | Lasem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lasem
# Processing Record 193 | Melbourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=melbourne
# Processing Record 194 | Baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=baykit
# Processing Record 195 | Diamantino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=diamantino
# Processing Record 196 | Kumluca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kumluca
# City not found. Skipping...
# Processing Record 197 | Izumo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=izumo
# Processing Record 198 | Biloela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=biloela
# City not found. Skipping...
# Processing Record 199 | Nacala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nacala
# Processing Record 200 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bonthe
# Processing Record 201 | Manzhouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=manzhouli
# Processing Record 202 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lasa
# City not found. Skipping...
# Processing Record 203 | Cervo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cervo
# Processing Record 204 | Puerto Madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto madryn
# Processing Record 205 | Saint-Joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-joseph
# Processing Record 206 | Wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=wanning
# Processing Record 207 | Tuma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tuma
# Processing Record 208 | Lazaro Cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lazaro cardenas
# Processing Record 209 | Scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=scarborough
# Processing Record 210 | Guilin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=guilin
# Processing Record 211 | Yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yumen
# City not found. Skipping...
# Processing Record 212 | Neryungri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=neryungri
# Processing Record 213 | Ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ambilobe
# Processing Record 214 | Mosquera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mosquera
# Processing Record 215 | Antropovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=antropovo
# Processing Record 216 | Valdez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=valdez
# Processing Record 217 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saskylakh
# Processing Record 218 | Massaguet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=massaguet
# Processing Record 219 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tasiilaq
# Processing Record 220 | Mokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mokolo
# Processing Record 221 | Lahat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lahat
# Processing Record 222 | Maniwaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=maniwaki
# Processing Record 223 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vila velha
# Processing Record 224 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vestmannaeyjar
# Processing Record 225 | Nikolayevsk-na-amure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nikolayevsk-na-amure
# Processing Record 226 | Barra Patuca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=barra patuca
# Processing Record 227 | Kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kenai
# Processing Record 228 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port hardy
# Processing Record 229 | Kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kawalu
# Processing Record 230 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao filipe
# Processing Record 231 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=isangel
# City not found. Skipping...
# Processing Record 232 | Racine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=racine
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 233 | Chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chicama
# City not found. Skipping...
# Processing Record 234 | Scottsbluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=scottsbluff
# Processing Record 235 | Emba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=emba
# Processing Record 236 | Challapata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=challapata
# Processing Record 237 | Kandy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kandy
# Processing Record 238 | Ati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ati
# Processing Record 239 | Port-Cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=port-cartier
# Processing Record 240 | Jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=jalu
# Processing Record 241 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-francois
# Processing Record 242 | Shangrao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=shangrao
# Processing Record 243 | Mohpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mohpa
# Processing Record 244 | Luau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=luau
# Processing Record 245 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=souillac
# Processing Record 246 | Durgapur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=durgapur
# Processing Record 247 | Linjiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=linjiang
# Processing Record 248 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ixtapa
# Processing Record 249 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ahipara
# Processing Record 250 | Katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=katsuura
# Processing Record 251 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=petropavlovsk-kamchatskiy
# Processing Record 252 | Zulueta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zulueta
# Processing Record 253 | Carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=carmen
# Processing Record 254 | Nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nemuro
# Processing Record 255 | Nerchinskiy Zavod
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nerchinskiy zavod
# Processing Record 256 | Lingao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lingao
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 257 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sao joao da barra
# Processing Record 258 | Armenis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=armenis
# Processing Record 259 | Deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=deputatskiy
# Processing Record 260 | Bandrele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bandrele
# City not found. Skipping...
# Processing Record 261 | Elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=elko
# Processing Record 262 | Divala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=divala
# City not found. Skipping...
# Processing Record 263 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chuy
# Processing Record 264 | Urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=urengoy
# Processing Record 265 | Laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=laguna
# Processing Record 266 | Ulaanbaatar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ulaanbaatar
# Processing Record 267 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saldanha
# Processing Record 268 | Fort-de-France
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fort-de-france
# Processing Record 269 | Yenotayevka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yenotayevka
# Processing Record 270 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hasaki
# Processing Record 271 | Yiyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yiyang
# Processing Record 272 | Lubao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lubao
# Processing Record 273 | Te Anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=te anau
# Processing Record 274 | Osypenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=osypenko
# Processing Record 275 | Mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mantua
# Processing Record 276 | Olinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=olinda
# Processing Record 277 | Monterey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=monterey
# Processing Record 278 | College
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=college
# Processing Record 279 | Mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mehamn
# Processing Record 280 | Chopda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chopda
# Processing Record 281 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chokurdakh
# Processing Record 282 | La Union
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=la union
# Processing Record 283 | Colares
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=colares
# Processing Record 284 | Tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=tual
# Processing Record 285 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=qaanaaq
# Processing Record 286 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=los llanos de aridane
# City not found. Skipping...
# Processing Record 287 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dingle
# Processing Record 288 | Hue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hue
# Processing Record 289 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=luderitz
# City not found. Skipping...
# Processing Record 290 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=leh
# Processing Record 291 | Vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vila
# Processing Record 292 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=namibe
# Processing Record 293 | Sistranda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sistranda
# Processing Record 294 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kavaratti
# Processing Record 295 | Keighley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=keighley
# Processing Record 296 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=buala
# Processing Record 297 | Batalha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=batalha
# Processing Record 298 | Maceio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=maceio
# Processing Record 299 | Rafai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rafai
# Processing Record 300 | Molteno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=molteno
# Processing Record 301 | Rabo de Peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rabo de peixe
# Processing Record 302 | Savinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=savinka
# Processing Record 303 | Griffith
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=griffith
# Processing Record 304 | Santa Maria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=santa maria
# Processing Record 305 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=codrington
# City not found. Skipping...
# Processing Record 306 | Glace Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=glace bay
# City not found. Skipping...
# Processing Record 307 | Berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=berlevag
# Processing Record 308 | Itacoatiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=itacoatiara
# Processing Record 309 | Chimbarongo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chimbarongo
# Processing Record 310 | Abu Zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=abu zabad
# Processing Record 311 | Puerto Colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=puerto colombia
# Processing Record 312 | Talara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=talara
# Processing Record 313 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bathsheba
# Processing Record 314 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kahului
# Processing Record 315 | Ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ketchikan
# Processing Record 316 | Ust-Maya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ust-maya
# Processing Record 317 | Luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=luanda
# Processing Record 318 | Monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=monrovia
# Processing Record 319 | Sakaiminato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sakaiminato
# Processing Record 320 | Svobodnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=svobodnyy
# Processing Record 321 | Guanare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=guanare
# Processing Record 322 | Lamar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=lamar
# ...
# Processing Record 446 | Labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=labuhan
# Processing Record 447 | Mul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mul
# Processing Record 448 | Chumikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chumikan
# Processing Record 449 | Rexburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rexburg
# Processing Record 450 | Del Rio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=del rio
# Processing Record 451 | Qujing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=qujing
# Processing Record 452 | Karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=karratha
# Processing Record 453 | Kayes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kayes
# Processing Record 454 | Trinidad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=trinidad
# Processing Record 455 | Axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=axim
# Processing Record 456 | Yar-Sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yar-sale
# Processing Record 457 | Egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=egvekinot
# Processing Record 458 | Taranagar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=taranagar
# Processing Record 459 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hambantota
# Processing Record 460 | Rogers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=rogers
# Processing Record 461 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=portland
# Processing Record 462 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=auki
# Processing Record 463 | Mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mitsamiouli
# Processing Record 464 | Hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hofn
# Processing Record 465 | Aurillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aurillac
# Processing Record 466 | Qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=qaqortoq
# Processing Record 467 | Fort Saint James
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fort saint james
# Processing Record 468 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=champerico
# Processing Record 469 | Aksay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aksay
# Processing Record 470 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=belyy yar
# Processing Record 471 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=meulaboh
# City not found. Skipping...
# Processing Record 472 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=alofi
# City not found. Skipping...
# Processing Record 473 | Banda Aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=banda aceh
# Processing Record 474 | Serebriya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=serebriya
# Processing Record 475 | The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=the valley
# Processing Record 476 | Kainan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kainan
# Processing Record 477 | Fond du Lac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=fond du lac
# Processing Record 478 | Nova Olimpia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nova olimpia
# City not found. Skipping...
# Processing Record 479 | Hovd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=hovd
# Processing Record 480 | Kalakamati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kalakamati
# Processing Record 481 | Mastic Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mastic beach
# Processing Record 482 | Snasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=snasa
# Processing Record 483 | Antalaha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=antalaha
# Processing Record 484 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=coquimbo
# Processing Record 485 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bandarbeyla
# Processing Record 486 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=coahuayana
# Processing Record 487 | Samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=samana
# Processing Record 488 | Nizwa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nizwa
# Processing Record 489 | Talcahuano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=talcahuano
# Processing Record 490 | Zhigansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=zhigansk
# Processing Record 491 | Taksimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=taksimo
# Processing Record 492 | Markova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=markova
# Processing Record 493 | Pitangui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=pitangui
# Processing Record 494 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aykhal
# Processing Record 495 | Afsin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=afsin
# Processing Record 496 | Kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kodinsk
# Processing Record 497 | South Lake Tahoe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=south lake tahoe
# Processing Record 498 | Savonlinna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=savonlinna
# City not found. Skipping...
# Processing Record 499 | Cartagena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=cartagena
# Processing Record 500 | Atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=atasu
# City not found. Skipping...
# Processing Record 501 | Inirida
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=inirida
# City not found. Skipping...
# Processing Record 502 | Maniitsoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=maniitsoq
# Processing Record 503 | Whitianga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=whitianga
# Processing Record 504 | Toccoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=toccoa
# Processing Record 505 | Ust-Barguzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ust-barguzin
# Processing Record 506 | Christchurch
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=christchurch
# City not found. Skipping...
# Processing Record 507 | Teahupoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=teahupoo
# Processing Record 508 | Santa Ana Huista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=santa ana huista
# Processing Record 509 | Kindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kindu
# Processing Record 510 | Phrae
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=phrae
# Processing Record 511 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=almaznyy
# City not found. Skipping...
# Processing Record 512 | Alihe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=alihe
# Processing Record 513 | Balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=balabac
# Processing Record 514 | Nueva Helvecia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=nueva helvecia
# Processing Record 515 | Peniche
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=peniche
# City not found. Skipping...
# Processing Record 516 | Paita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=paita
# Processing Record 517 | Elizabeth City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=elizabeth city
# Processing Record 518 | Severodvinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=severodvinsk
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 519 | Davila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=davila
# City not found. Skipping...
# Processing Record 520 | Boa Vista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=boa vista
# Processing Record 521 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=ostrovnoy
# City not found. Skipping...
# Processing Record 522 | Isetskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=isetskoye
# Processing Record 523 | San Quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=san quintin
# Processing Record 524 | Provost
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=provost
# Processing Record 525 | Madingou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=madingou
# Processing Record 526 | Albert Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=albert town
# Processing Record 527 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=saint-pierre
# Processing Record 528 | Sault Sainte Marie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=sault sainte marie
# Processing Record 529 | Makat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=makat
# Processing Record 530 | Arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=arlit
# City not found. Skipping...
# Processing Record 531 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=yerbogachen
# Processing Record 532 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=kamenka
# Processing Record 533 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vostok
# Processing Record 534 | Bet Shemesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bet shemesh
# Processing Record 535 | Seymchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=seymchan
# Processing Record 536 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dwarka
# Processing Record 537 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=aklavik
# Processing Record 538 | Vila Praia de Ancora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=vila praia de ancora
# Processing Record 539 | Bacalar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bacalar
# Processing Record 540 | Dombarovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=dombarovskiy
# Processing Record 541 | Poopo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=poopo
# Processing Record 542 | Voi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=voi
# Processing Record 543 | Jiayuguan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=jiayuguan
# Processing Record 544 | Bara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=bara
# Processing Record 545 | La Baule-Escoublac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=la baule-escoublac
# Processing Record 546 | Osmena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=osmena
# Processing Record 547 | Mae Sai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=mae sai
# City not found. Skipping...
# Processing Record 548 | Binzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=binzhou
# Processing Record 549 | Oxford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=oxford
# Processing Record 550 | Snezhnogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=snezhnogorsk
# City not found. Skipping...
# Processing Record 551 | Chernyshevskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=81c775e0ef24653ff64a0196e83389b1&q=chernyshevskiy

# %%
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lompoc
# Processing Record 2 of Set 1 | klaksvik
# Processing Record 3 of Set 1 | bisignano
# Processing Record 4 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | ashland
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | haines junction
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | port macquarie
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | saint-philippe
# Processing Record 19 of Set 1 | kaitangata
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | srednekolymsk
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | severo-kurilsk
# Processing Record 24 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 1 | ivaipora
# City not found. Skipping...
# Processing Record 26 of Set 1 | cape town
# Processing Record 27 of Set 1 | ambilobe
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | namatanai
# Processing Record 31 of Set 1 | scottsburgh
# City not found. Skipping...
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | khormuj
# City not found. Skipping...
# Processing Record 34 of Set 1 | kodiak
# Processing Record 35 of Set 1 | muros
# Processing Record 36 of Set 1 | tamandare
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | lumut
# Processing Record 40 of Set 1 | sukumo
# Processing Record 41 of Set 1 | chapais
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | ordzhonikidze
# Processing Record 44 of Set 1 | jiangyou
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | vila franca do campo
# Processing Record 47 of Set 1 | shchelkun
# Processing Record 48 of Set 1 | vanimo
# Processing Record 49 of Set 1 | kalmanhaza
# Processing Record 50 of Set 1 | butaritari
# Processing Record 0 of Set 2 | codrington
# Processing Record 1 of Set 2 | ayolas
# Processing Record 2 of Set 2 | kapaa
# Processing Record 3 of Set 2 | east london
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | tessalit
# Processing Record 6 of Set 2 | panguna
# Processing Record 7 of Set 2 | cockburn town
# Processing Record 8 of Set 2 | valerianovsk
# Processing Record 9 of Set 2 | tingrela
# City not found. Skipping...
# Processing Record 10 of Set 2 | novobirilyussy
# Processing Record 11 of Set 2 | krasnoborsk
# Processing Record 12 of Set 2 | mar del plata
# Processing Record 13 of Set 2 | new norfolk
# Processing Record 14 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 15 of Set 2 | vila do maio
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 2 | livani
# Processing Record 21 of Set 2 | urucui
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 2 | tuatapere
# Processing Record 26 of Set 2 | bocaiuva
# Processing Record 27 of Set 2 | jiexiu
# Processing Record 28 of Set 2 | quelimane
# Processing Record 29 of Set 2 | rujewa
# Processing Record 30 of Set 2 | cherskiy
# Processing Record 31 of Set 2 | port elizabeth
# Processing Record 32 of Set 2 | yanchukan
# City not found. Skipping...
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | belyy yar
# Processing Record 35 of Set 2 | venezuela
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | mitsamiouli
# Processing Record 40 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 41 of Set 2 | bunia
# Processing Record 42 of Set 2 | boa vista
# Processing Record 43 of Set 2 | kudahuvadhoo
# Processing Record 44 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 2 | bluff
# Processing Record 46 of Set 2 | okhotsk
# Processing Record 47 of Set 2 | muzaffarabad
# Processing Record 48 of Set 2 | avarua
# Processing Record 49 of Set 2 | esperance
# Processing Record 0 of Set 3 | arenapolis
# Processing Record 1 of Set 3 | tuktoyaktuk
# Processing Record 2 of Set 3 | nemuro
# Processing Record 3 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 3 | rio gallegos
# Processing Record 5 of Set 3 | svetlaya
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | caravelas
# Processing Record 8 of Set 3 | karamea
# City not found. Skipping...
# Processing Record 9 of Set 3 | mandalgovi
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | atuona
# Processing Record 12 of Set 3 | pemangkat
# City not found. Skipping...
# Processing Record 13 of Set 3 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 3 | qiqihar
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | komsomolskiy
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | amnat charoen
# Processing Record 21 of Set 3 | provideniya
# Processing Record 22 of Set 3 | luang prabang
# Processing Record 23 of Set 3 | hami
# Processing Record 24 of Set 3 | saskylakh
# Processing Record 25 of Set 3 | kyren
# Processing Record 26 of Set 3 | yuanping
# Processing Record 27 of Set 3 | dukat
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | dorfen
# Processing Record 31 of Set 3 | ayan
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 3 | vertientes
# Processing Record 36 of Set 3 | charters towers
# Processing Record 37 of Set 3 | nenjiang
# Processing Record 38 of Set 3 | hermanus
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | puerto del rosario
# Processing Record 41 of Set 3 | husavik
# Processing Record 42 of Set 3 | maldonado
# Processing Record 43 of Set 3 | bintulu
# Processing Record 44 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 3 | luderitz
# Processing Record 46 of Set 3 | vardo
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | muzhi
# Processing Record 49 of Set 3 | zhangye
# Processing Record 0 of Set 4 | nouadhibou
# Processing Record 1 of Set 4 | oussouye
# Processing Record 2 of Set 4 | agaro
# Processing Record 3 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 4 | tasiilaq
# Processing Record 5 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 4 | bathsheba
# Processing Record 7 of Set 4 | pacific grove
# Processing Record 8 of Set 4 | half moon bay
# Processing Record 9 of Set 4 | goderich
# Processing Record 10 of Set 4 | severnyy
# City not found. Skipping...
# Processing Record 11 of Set 4 | erenhot
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | agadez
# Processing Record 14 of Set 4 | hobart
# Processing Record 15 of Set 4 | drummondville
# Processing Record 16 of Set 4 | selfoss
# Processing Record 17 of Set 4 | carman
# Processing Record 18 of Set 4 | kurumkan
# Processing Record 19 of Set 4 | rawson
# Processing Record 20 of Set 4 | osakarovka
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | pec
# Processing Record 23 of Set 4 | nacala
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | ewo
# Processing Record 26 of Set 4 | alihe
# Processing Record 27 of Set 4 | felipe carrillo puerto
# Processing Record 28 of Set 4 | sept-iles
# Processing Record 29 of Set 4 | anzio
# Processing Record 30 of Set 4 | abeche
# Processing Record 31 of Set 4 | chokurdakh
# Processing Record 32 of Set 4 | sao filipe
# Processing Record 33 of Set 4 | yatou
# Processing Record 34 of Set 4 | pangkalanbuun
# Processing Record 35 of Set 4 | namibe
# Processing Record 36 of Set 4 | caltagirone
# Processing Record 37 of Set 4 | araguacu
# City not found. Skipping...
# Processing Record 38 of Set 4 | atuntaqui
# Processing Record 39 of Set 4 | marshfield
# Processing Record 40 of Set 4 | saint-joseph
# Processing Record 41 of Set 4 | chambas
# Processing Record 42 of Set 4 | mahebourg
# Processing Record 43 of Set 4 | abadan
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | axim
# Processing Record 46 of Set 4 | sioux lookout
# Processing Record 47 of Set 4 | voh
# Processing Record 48 of Set 4 | puerto ayora
# Processing Record 49 of Set 4 | sinnamary
# Processing Record 0 of Set 5 | duz
# City not found. Skipping...
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | port hardy
# Processing Record 3 of Set 5 | vieste
# Processing Record 4 of Set 5 | dalvik
# Processing Record 5 of Set 5 | tual
# Processing Record 6 of Set 5 | novopokrovka
# Processing Record 7 of Set 5 | soyo
# Processing Record 8 of Set 5 | broken hill
# Processing Record 9 of Set 5 | columbia
# Processing Record 10 of Set 5 | sao joao da barra
# Processing Record 11 of Set 5 | lumphat
# Processing Record 12 of Set 5 | ciudad bolivar
# Processing Record 13 of Set 5 | san quintin
# Processing Record 14 of Set 5 | bredasdorp
# Processing Record 15 of Set 5 | torbay
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | tabarqah
# City not found. Skipping...
# Processing Record 18 of Set 5 | vila velha
# Processing Record 19 of Set 5 | samaniego
# Processing Record 20 of Set 5 | kruisfontein
# Processing Record 21 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 5 | dunedin
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | geraldton
# Processing Record 25 of Set 5 | sarangani
# Processing Record 26 of Set 5 | bontang
# Processing Record 27 of Set 5 | jacareacanga
# Processing Record 28 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 5 | raudeberg
# Processing Record 30 of Set 5 | terrenate
# Processing Record 31 of Set 5 | vao
# Processing Record 32 of Set 5 | asau
# City not found. Skipping...
# Processing Record 33 of Set 5 | hovd
# Processing Record 34 of Set 5 | bure
# Processing Record 35 of Set 5 | ranot
# Processing Record 36 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 37 of Set 5 | merauke
# Processing Record 38 of Set 5 | prichard
# Processing Record 39 of Set 5 | gravelbourg
# Processing Record 40 of Set 5 | searcy
# Processing Record 41 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | sisimiut
# Processing Record 44 of Set 5 | trelew
# Processing Record 45 of Set 5 | aban
# City not found. Skipping...
# Processing Record 46 of Set 5 | vakhrushev
# Processing Record 47 of Set 5 | pierre
# Processing Record 48 of Set 5 | ilulissat
# Processing Record 49 of Set 5 | lorengau
# Processing Record 0 of Set 6 | mokrousovo
# Processing Record 1 of Set 6 | baltay
# Processing Record 2 of Set 6 | kainantu
# Processing Record 3 of Set 6 | goulburn
# Processing Record 4 of Set 6 | lincoln
# Processing Record 5 of Set 6 | harnosand
# Processing Record 6 of Set 6 | camana
# City not found. Skipping...
# Processing Record 7 of Set 6 | pleshanovo
# Processing Record 8 of Set 6 | ostrovnoy
# Processing Record 9 of Set 6 | porto novo
# Processing Record 10 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 11 of Set 6 | quatre cocos
# Processing Record 12 of Set 6 | marzuq
# Processing Record 13 of Set 6 | prince george
# Processing Record 14 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 6 | sorsk
# Processing Record 16 of Set 6 | port blair
# Processing Record 17 of Set 6 | shihezi
# Processing Record 18 of Set 6 | coffs harbour
# Processing Record 19 of Set 6 | rasova
# Processing Record 20 of Set 6 | dingle
# Processing Record 21 of Set 6 | la primavera
# Processing Record 22 of Set 6 | tezu
# Processing Record 23 of Set 6 | qasigiannguit
# Processing Record 24 of Set 6 | westport
# Processing Record 25 of Set 6 | peleduy
# Processing Record 26 of Set 6 | yei
# City not found. Skipping...
# Processing Record 27 of Set 6 | dakar
# Processing Record 28 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 29 of Set 6 | pisco
# Processing Record 30 of Set 6 | buzuluk
# Processing Record 31 of Set 6 | jahrom
# City not found. Skipping...
# Processing Record 32 of Set 6 | ponferrada
# Processing Record 33 of Set 6 | kaeo
# Processing Record 34 of Set 6 | chimbote
# Processing Record 35 of Set 6 | rocha
# Processing Record 36 of Set 6 | kurkino
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | puri
# Processing Record 39 of Set 6 | maues
# Processing Record 40 of Set 6 | kapit
# Processing Record 41 of Set 6 | sinegorye
# Processing Record 42 of Set 6 | thompson
# Processing Record 43 of Set 6 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 6 | itaueira
# Processing Record 45 of Set 6 | georgetown
# Processing Record 46 of Set 6 | parana
# Processing Record 47 of Set 6 | govindgarh
# Processing Record 48 of Set 6 | laguna
# Processing Record 49 of Set 6 | tura
# Processing Record 0 of Set 7 | nhulunbuy
# Processing Record 1 of Set 7 | buala
# Processing Record 2 of Set 7 | ngunguru
# Processing Record 3 of Set 7 | abu zabad
# Processing Record 4 of Set 7 | katete
# Processing Record 5 of Set 7 | flin flon
# Processing Record 6 of Set 7 | fayaoue
# Processing Record 7 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | omsukchan
# Processing Record 10 of Set 7 | la asuncion
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | matagami
# Processing Record 13 of Set 7 | palmer
# Processing Record 14 of Set 7 | dzhebariki-khaya
# Processing Record 15 of Set 7 | shitanjing
# Processing Record 16 of Set 7 | ixtapa
# Processing Record 17 of Set 7 | bethel
# Processing Record 18 of Set 7 | khani
# Processing Record 19 of Set 7 | saint george
# Processing Record 20 of Set 7 | whitehorse
# Processing Record 21 of Set 7 | isiolo
# Processing Record 22 of Set 7 | sao paulo de olivenca
# Processing Record 23 of Set 7 | buckeye
# Processing Record 24 of Set 7 | wewak
# Processing Record 25 of Set 7 | huarmey
# Processing Record 26 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 27 of Set 7 | la libertad
# Processing Record 28 of Set 7 | norman wells
# Processing Record 29 of Set 7 | dicabisagan
# Processing Record 30 of Set 7 | kavieng
# Processing Record 31 of Set 7 | wladyslawowo
# Processing Record 32 of Set 7 | kemin
# Processing Record 33 of Set 7 | coolum beach
# Processing Record 34 of Set 7 | rosetta
# Processing Record 35 of Set 7 | bermeo
# Processing Record 36 of Set 7 | turtas
# Processing Record 37 of Set 7 | mount gambier
# Processing Record 38 of Set 7 | key west
# Processing Record 39 of Set 7 | aklavik
# Processing Record 40 of Set 7 | tikapur
# Processing Record 41 of Set 7 | oranjestad
# Processing Record 42 of Set 7 | calvinia
# Processing Record 43 of Set 7 | kahului
# Processing Record 44 of Set 7 | gaziantep
# Processing Record 45 of Set 7 | port augusta
# Processing Record 46 of Set 7 | turukhansk
# Processing Record 47 of Set 7 | roma
# Processing Record 48 of Set 7 | buraydah
# Processing Record 49 of Set 7 | andenes
# City not found. Skipping...
# Processing Record 0 of Set 8 | coihaique
# Processing Record 1 of Set 8 | surt
# Processing Record 2 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 8 | nanjangud
# Processing Record 4 of Set 8 | saravan
# Processing Record 5 of Set 8 | penzance
# Processing Record 6 of Set 8 | mehamn
# Processing Record 7 of Set 8 | baherden
# Processing Record 8 of Set 8 | minbu
# Processing Record 9 of Set 8 | hamina
# Processing Record 10 of Set 8 | mackay
# Processing Record 11 of Set 8 | omaruru
# Processing Record 12 of Set 8 | roald
# Processing Record 13 of Set 8 | tashtyp
# Processing Record 14 of Set 8 | kyra
# City not found. Skipping...
# Processing Record 15 of Set 8 | walvis bay
# Processing Record 16 of Set 8 | kloulklubed
# Processing Record 17 of Set 8 | le port
# Processing Record 18 of Set 8 | hokitika
# Processing Record 19 of Set 8 | guapi
# Processing Record 20 of Set 8 | manyana
# Processing Record 21 of Set 8 | airai
# Processing Record 22 of Set 8 | wajid
# Processing Record 23 of Set 8 | mumford
# Processing Record 24 of Set 8 | labuhan
# Processing Record 25 of Set 8 | sabang
# Processing Record 26 of Set 8 | batagay-alyta
# Processing Record 27 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 28 of Set 8 | gouyave
# Processing Record 29 of Set 8 | avera
# Processing Record 30 of Set 8 | zonguldak
# Processing Record 31 of Set 8 | tokur
# Processing Record 32 of Set 8 | pyay
# Processing Record 33 of Set 8 | ulladulla
# Processing Record 34 of Set 8 | grand-santi
# Processing Record 35 of Set 8 | urusha
# Processing Record 36 of Set 8 | lata
# Processing Record 37 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 38 of Set 8 | tazovskiy
# Processing Record 39 of Set 8 | kefamenanu
# Processing Record 40 of Set 8 | agva
# City not found. Skipping...
# Processing Record 41 of Set 8 | kysyl-syr
# Processing Record 42 of Set 8 | wajima
# Processing Record 43 of Set 8 | kargopol
# Processing Record 44 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 45 of Set 8 | ovalle
# Processing Record 46 of Set 8 | wadi musa
# Processing Record 47 of Set 8 | iguape
# Processing Record 48 of Set 8 | san juan
# Processing Record 49 of Set 8 | vinh
# Processing Record 0 of Set 9 | kuminskiy
# Processing Record 1 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 9 | honningsvag
# Processing Record 3 of Set 9 | harper
# Processing Record 4 of Set 9 | batasan
# Processing Record 5 of Set 9 | yumen
# Processing Record 6 of Set 9 | tutoia
# Processing Record 7 of Set 9 | tazmalt
# Processing Record 8 of Set 9 | lavrentiya
# Processing Record 9 of Set 9 | sarmanovo
# Processing Record 10 of Set 9 | edgewater
# Processing Record 11 of Set 9 | gushikawa
# Processing Record 12 of Set 9 | kalmunai
# Processing Record 13 of Set 9 | houma
# Processing Record 14 of Set 9 | vila
# Processing Record 15 of Set 9 | umba
# Processing Record 16 of Set 9 | pevek
# Processing Record 17 of Set 9 | adrar
# Processing Record 18 of Set 9 | termiz
# Processing Record 19 of Set 9 | luanda
# Processing Record 20 of Set 9 | maniitsoq
# Processing Record 21 of Set 9 | yuncheng
# Processing Record 22 of Set 9 | port shepstone
# Processing Record 23 of Set 9 | truth or consequences
# Processing Record 24 of Set 9 | acapulco
# Processing Record 25 of Set 9 | necochea
# Processing Record 26 of Set 9 | broome
# Processing Record 27 of Set 9 | laredo
# Processing Record 28 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 9 | fort smith
# Processing Record 30 of Set 9 | comodoro rivadavia
# Processing Record 31 of Set 9 | ferme-neuve
# Processing Record 32 of Set 9 | dengzhou
# Processing Record 33 of Set 9 | kamennogorsk
# Processing Record 34 of Set 9 | padang
# Processing Record 35 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | huangchuan
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | sur
# Processing Record 40 of Set 9 | tocopilla
# Processing Record 41 of Set 9 | rudbar
# City not found. Skipping...
# Processing Record 42 of Set 9 | galesong
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | narsaq
# Processing Record 45 of Set 9 | sungaipenuh
# Processing Record 46 of Set 9 | papara
# Processing Record 47 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 48 of Set 9 | isangel
# Processing Record 49 of Set 9 | kamyshlov
# Processing Record 0 of Set 10 | ponta do sol
# Processing Record 1 of Set 10 | lengshuitan
# Processing Record 2 of Set 10 | thinadhoo
# Processing Record 3 of Set 10 | saint anthony
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | kokopo
# Processing Record 6 of Set 10 | iqaluit
# Processing Record 7 of Set 10 | longyearbyen
# Processing Record 8 of Set 10 | los llanos de aridane
# Processing Record 9 of Set 10 | hayden
# Processing Record 10 of Set 10 | erzurum
# Processing Record 11 of Set 10 | bonthe
# Processing Record 12 of Set 10 | ketchikan
# Processing Record 13 of Set 10 | barkhan
# Processing Record 14 of Set 10 | euclides da cunha
# Processing Record 15 of Set 10 | sanghar
# Processing Record 16 of Set 10 | te anau
# Processing Record 17 of Set 10 | valleyview
# Processing Record 18 of Set 10 | cidreira
# Processing Record 19 of Set 10 | banda aceh
# Processing Record 20 of Set 10 | tagusao
# Processing Record 21 of Set 10 | terrace
# Processing Record 22 of Set 10 | el chichicaste
# Processing Record 23 of Set 10 | gberia fotombu
# Processing Record 24 of Set 10 | ranir bazar
# Processing Record 25 of Set 10 | grindsted
# Processing Record 26 of Set 10 | katsuura
# Processing Record 27 of Set 10 | qaqortoq
# Processing Record 28 of Set 10 | pontes e lacerda
# Processing Record 29 of Set 10 | bata
# Processing Record 30 of Set 10 | kingston
# Processing Record 31 of Set 10 | aleksandrovka
# Processing Record 32 of Set 10 | vostok
# Processing Record 33 of Set 10 | puerto madryn
# Processing Record 34 of Set 10 | yuzhnyy
# Processing Record 35 of Set 10 | bulungu
# Processing Record 36 of Set 10 | kollam
# Processing Record 37 of Set 10 | progreso
# Processing Record 38 of Set 10 | visby
# Processing Record 39 of Set 10 | ilebo
# Processing Record 40 of Set 10 | ajdabiya
# Processing Record 41 of Set 10 | maine-soroa
# Processing Record 42 of Set 10 | sayreville
# Processing Record 43 of Set 10 | palana
# Processing Record 44 of Set 10 | acajutiba
# Processing Record 45 of Set 10 | lakatoro
# Processing Record 46 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 47 of Set 10 | lakes entrance
# Processing Record 48 of Set 10 | ludza
# Processing Record 49 of Set 10 | zvishavane
# Processing Record 0 of Set 11 | mao
# Processing Record 1 of Set 11 | seaham
# Processing Record 2 of Set 11 | kaa-khem
# Processing Record 3 of Set 11 | grindavik
# Processing Record 4 of Set 11 | pangody
# Processing Record 5 of Set 11 | zhuzhou
# Processing Record 6 of Set 11 | clyde river
# Processing Record 7 of Set 11 | estelle
# Processing Record 8 of Set 11 | ulaanbaatar
# Processing Record 9 of Set 11 | victoria point
# Processing Record 10 of Set 11 | flores
# Processing Record 11 of Set 11 | cairns
# Processing Record 12 of Set 11 | beyneu
# Processing Record 13 of Set 11 | hoquiam
# Processing Record 14 of Set 11 | kurilsk
# Processing Record 15 of Set 11 | albuquerque
# Processing Record 16 of Set 11 | tomatlan
# Processing Record 17 of Set 11 | blackfoot
# Processing Record 18 of Set 11 | anito
# Processing Record 19 of Set 11 | meybod
# Processing Record 20 of Set 11 | muscat
# Processing Record 21 of Set 11 | san patricio
# Processing Record 22 of Set 11 | pali
# Processing Record 23 of Set 11 | atambua
# Processing Record 24 of Set 11 | mocambique
# City not found. Skipping...
# Processing Record 25 of Set 11 | kuytun
# Processing Record 26 of Set 11 | lamu
# Processing Record 27 of Set 11 | bandarbeyla
# Processing Record 28 of Set 11 | eenhana
# Processing Record 29 of Set 11 | newburn
# Processing Record 30 of Set 11 | changli
# Processing Record 31 of Set 11 | toowoomba
# Processing Record 32 of Set 11 | banjar
# Processing Record 33 of Set 11 | hohhot
# Processing Record 34 of Set 11 | debre birhan
# Processing Record 35 of Set 11 | nelson bay
# Processing Record 36 of Set 11 | sibu
# Processing Record 37 of Set 11 | black river
# City not found. Skipping...
# Processing Record 38 of Set 11 | thaba-tseka
# Processing Record 39 of Set 11 | hobyo
# Processing Record 40 of Set 11 | bela vista de goias
# Processing Record 41 of Set 11 | ugoofaaru
# Processing Record 42 of Set 11 | dali
# Processing Record 43 of Set 11 | kadaya
# Processing Record 44 of Set 11 | kensington
# Processing Record 45 of Set 11 | zhigansk
# Processing Record 46 of Set 11 | merritt island
# Processing Record 47 of Set 11 | yamada
# Processing Record 48 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 11 | baghdad
# Processing Record 0 of Set 12 | havre-saint-pierre
# Processing Record 1 of Set 12 | alta floresta
# Processing Record 2 of Set 12 | rio grande
# Processing Record 3 of Set 12 | wuwei
# Processing Record 4 of Set 12 | arman
# Processing Record 5 of Set 12 | salamiyah
# Processing Record 6 of Set 12 | vestmannaeyjar
# Processing Record 7 of Set 12 | dondo
# Processing Record 8 of Set 12 | gallup
# Processing Record 9 of Set 12 | micheweni
# Processing Record 10 of Set 12 | yanam
# Processing Record 11 of Set 12 | nipawin
# Processing Record 12 of Set 12 | jalu
# Processing Record 13 of Set 12 | brae
# Processing Record 14 of Set 12 | alappuzha
# City not found. Skipping...
# Processing Record 15 of Set 12 | leonidovo
# Processing Record 16 of Set 12 | krasnyy yar
# Processing Record 17 of Set 12 | nyimba
# Processing Record 18 of Set 12 | simao
# Processing Record 19 of Set 12 | kharsia
# Processing Record 20 of Set 12 | asekeyevo
# Processing Record 21 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 22 of Set 12 | les herbiers
# Processing Record 23 of Set 12 | bonavista
# Processing Record 24 of Set 12 | belaya gora
# Processing Record 25 of Set 12 | gao
# Processing Record 26 of Set 12 | yerbogachen
# Processing Record 27 of Set 12 | porechye-rybnoye
# Processing Record 28 of Set 12 | san andres
# Processing Record 29 of Set 12 | fairbanks
# Processing Record 30 of Set 12 | george
# Processing Record 31 of Set 12 | bradford
# Processing Record 32 of Set 12 | lago da pedra
# City not found. Skipping...
# Processing Record 33 of Set 12 | jomalig
# City not found. Skipping...
# Processing Record 34 of Set 12 | port lincoln
# Processing Record 35 of Set 12 | carutapera
# Processing Record 36 of Set 12 | awjilah
# Processing Record 37 of Set 12 | naryan-mar
# Processing Record 38 of Set 12 | la ronge
# Processing Record 39 of Set 12 | natal
# Processing Record 40 of Set 12 | nevsehir
# Processing Record 41 of Set 12 | turayf
# Processing Record 42 of Set 12 | temiscaming
# Processing Record 43 of Set 12 | gardan diwal
# City not found. Skipping...
# Processing Record 44 of Set 12 | kupang
# Processing Record 45 of Set 12 | port-cartier
# Processing Record 46 of Set 12 | storm lake
# Processing Record 47 of Set 12 | manokwari
# Processing Record 48 of Set 12 | julich
# Processing Record 49 of Set 12 | makung
# City not found. Skipping...
# Processing Record 0 of Set 13 | viedma
# Processing Record 1 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 13 | sarkand
# Processing Record 3 of Set 13 | jhang
# Processing Record 4 of Set 13 | naze
# Processing Record 5 of Set 13 | zory
# Processing Record 6 of Set 13 | labuan
# Processing Record 7 of Set 13 | luwuk
# Processing Record 8 of Set 13 | sao felix do xingu
# Processing Record 9 of Set 13 | fonte boa
# Processing Record 10 of Set 13 | mahibadhoo
# Processing Record 11 of Set 13 | loukhi
# Processing Record 12 of Set 13 | mount isa
# Processing Record 13 of Set 13 | kargasok
# Processing Record 14 of Set 13 | mandera
# Processing Record 15 of Set 13 | praya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Display data frame head 
weather_data.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0       Lorengau         100      PG  1559535349        87  -2.02  147.27
# 1       Fairview          90      US  1559535351        77  40.81  -74.00
# 2  Alice Springs           0      AU  1559535126        44 -23.70  133.88
# 3          Arica          40      CL  1559535353        71 -18.48  -70.32
# 4      Carnarvon           0      ZA  1559535354        44 -30.97   22.13
#
#    Max Temp  Wind Speed
# 0     82.17        6.40
# 1     66.20        6.93
# 2     59.00       18.34
# 3     57.20        6.93
# 4     52.11        5.23

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()
